# %% [markdown]
# # Lecture 23
#
# ### pandas; Selecting Columns; Selecting Rows; Pause; Column Operations; Broadcasting; Boolean Indexing; More Sophisticated Boolean Operations; Iterating Through Rows; Basic Statistics; Dropping Missing Values With .dropna(), Sorting With .sort_values(), Scatter Plot; Summary; Recursion

# %% [markdown]
# # 1. pandas
#
# ### * pandas (the name comes from "panel data") is a package that allows you create objects called `DataFrames`, which, roughly speaking, function as spreadsheet tables.

# %%
# EXAMPLE 1a: A pandas DataFrame

import pandas as pd # "pd" is a widely used nick-name for the pandas module.

netflix_df = pd.read_csv('netflix.csv')

print('############################\nnetflix_df.columns:\n############################\n')
print(netflix_df.columns)

print('\n')

print('############################\nnetflix_df.head():\n############################\n')
print(netflix_df.head())
# Out:
# ############################
# netflix_df.columns:
# ############################
#
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')
#
#
# ############################
# netflix_df.head():
# ############################
#
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# 3          Series               7.7
# 4           Movie               8.1
#
#                                 Country Availability       Runtime  \
# 0                                           Thailand  < 30 minutes
# 1                                             Canada      1-2 hour
# 2                                             Canada      1-2 hour
# 3                                Belgium,Netherlands  < 30 minutes
# 4  Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
#
#           Director                      Writer  ... Netflix Release Date  \
# 0  Tomas Alfredson       John Ajvide Lindqvist  ...             3/4/2021
# 1    Coky Giedroyc               Caitlin Moran  ...             3/4/2021
# 2    Brendan Walsh  Brendan Walsh, Daley Nixon  ...             3/4/2021
# 3              NaN                         NaN  ...             3/4/2021
# 4    Stephen Irwin                         NaN  ...             3/4/2021
#
#                          Production House  \
# 0               Canal+, Sandrew Metronome
# 1  Film 4, Monumental Pictures, Lionsgate
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                              Netflix Link  \
# 0  https://www.netflix.com/watch/81415947
# 1  https://www.netflix.com/watch/81041267
# 2  https://www.netflix.com/watch/81305978
# 3  https://www.netflix.com/watch/81336456
# 4  https://www.netflix.com/watch/81078393
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
# 1  https://www.imdb.com/title/tt4193072
# 2  https://www.imdb.com/title/tt8945942
# 3  https://www.imdb.com/title/tt6132758
# 4  https://www.imdb.com/title/tt2023611
#
#                                              Summary  IMDb Votes  \
# 0  A med student with a supernatural gift tries t...    205926.0
# 1  When nerdy Johanna moves to London, things get...      2838.0
# 2  Trapped in a frozen car during a blizzard, a p...      1720.0
# 3  Upon moving into a new place, a 20-something r...      1147.0
# 4  Inspired by her moms rebellious past and a con...        63.0
#
#                                                Image  \
# 0  https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
# 1  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 2  https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 3  https://occ-0-1489-1490.1.nflxso.net/dnm/api/v...
# 4  https://occ-0-4039-1500.1.nflxso.net/dnm/api/v...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BOWM4NT...
# 1  https://m.media-amazon.com/images/M/MV5BZGUyN2...
# 2  https://m.media-amazon.com/images/M/MV5BODM2MD...
# 3  https://m.media-amazon.com/images/M/MV5BNWRkMz...
# 4  https://m.media-amazon.com/images/M/MV5BODYyNW...
#
#                                   TMDb Trailer Trailer Site
# 0                                          NaN          NaN
# 1  https://www.youtube.com/watch?v=eIbcxPy4okQ      YouTube
# 2  https://www.youtube.com/watch?v=0RvV7TNUlkQ      YouTube
# 3                                          NaN          NaN
# 4                                          NaN          NaN
#
# [5 rows x 29 columns]

# %%
# EXAMPLE 1b: Printing the DataFrame

import pandas as pd
netflix_df = pd.read_csv('netflix.csv')

print(netflix_df)
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# 15475                                     NaN
# 15476                                     NaN
# 15477               Animation, Comedy, Family
# 15478               Animation, Comedy, Family
# 15479       Animation, Action, Comedy, Family
#
#                                                     Tags         Languages  \
# 0      Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1           Dramas,Comedies,Films Based on Books,British           English
# 2                                              Thrillers           English
# 3            TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4      Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
# ...                                                  ...               ...
# 15475  TV Dramas,TV Programmes,TV Comedies,Romantic T...               NaN
# 15476  Animal Tales,Family Comedies,Family Adventures...               NaN
# 15477  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...           English
# 15478  TV Comedies,Kids TV,TV Cartoons,TV Programmes,...           English
# 15479  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...           English
#
#       Series or Movie  Hidden Gem Score  \
# 0              Series               4.3
# 1               Movie               7.0
# 2               Movie               6.4
# 3              Series               7.7
# 4               Movie               8.1
# ...               ...               ...
# 15475          Series               NaN
# 15476          Series               NaN
# 15477          Series               8.4
# 15478          Series               8.2
# 15479          Series               8.1
#
#                                     Country Availability       Runtime  \
# 0                                               Thailand  < 30 minutes
# 1                                                 Canada      1-2 hour
# 2                                                 Canada      1-2 hour
# 3                                    Belgium,Netherlands  < 30 minutes
# 4      Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
# ...                                                  ...           ...
# 15475  South Korea,Argentina,United Kingdom,Australia...  < 30 minutes
# 15476  Russia,Hong Kong,Hungary,Australia,South Korea...  < 30 minutes
# 15477  Belgium,Switzerland,United States,Germany,Unit...  < 30 minutes
# 15478  Belgium,Switzerland,Germany,Argentina,United K...  < 30 minutes
# 15479  Belgium,Switzerland,Germany,United Kingdom,Fra...  < 30 minutes
#
#               Director                      Writer  ... Netflix Release Date  \
# 0      Tomas Alfredson       John Ajvide Lindqvist  ...             3/4/2021
# 1        Coky Giedroyc               Caitlin Moran  ...             3/4/2021
# 2        Brendan Walsh  Brendan Walsh, Daley Nixon  ...             3/4/2021
# 3                  NaN                         NaN  ...             3/4/2021
# 4        Stephen Irwin                         NaN  ...             3/4/2021
# ...                ...                         ...  ...                  ...
# 15475              NaN                         NaN  ...            4/14/2015
# 15476              NaN                         NaN  ...            4/14/2015
# 15477              NaN                         NaN  ...            4/14/2015
# 15478              NaN                         NaN  ...            4/14/2015
# 15479              NaN                         NaN  ...            4/14/2015
#
#                              Production House  \
# 0                   Canal+, Sandrew Metronome
# 1      Film 4, Monumental Pictures, Lionsgate
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 15475                                     NaN
# 15476                                     NaN
# 15477                                     NaN
# 15478                                     Fox
# 15479                                     NaN
#
#                                  Netflix Link  \
# 0      https://www.netflix.com/watch/81415947
# 1      https://www.netflix.com/watch/81041267
# 2      https://www.netflix.com/watch/81305978
# 3      https://www.netflix.com/watch/81336456
# 4      https://www.netflix.com/watch/81078393
# ...                                       ...
# 15475  https://www.netflix.com/watch/80031595
# 15476  https://www.netflix.com/watch/70242630
# 15477  https://www.netflix.com/watch/70259784
# 15478  https://www.netflix.com/watch/70221348
# 15479  https://www.netflix.com/watch/70241791
#
#                                   IMDb Link  \
# 0      https://www.imdb.com/title/tt1139797
# 1      https://www.imdb.com/title/tt4193072
# 2      https://www.imdb.com/title/tt8945942
# 3      https://www.imdb.com/title/tt6132758
# 4      https://www.imdb.com/title/tt2023611
# ...                                     ...
# 15475                                   NaN
# 15476                                   NaN
# 15477                                   NaN
# 15478                                   NaN
# 15479                                   NaN
#
#                                                  Summary  IMDb Votes  \
# 0      A med student with a supernatural gift tries t...    205926.0
# 1      When nerdy Johanna moves to London, things get...      2838.0
# 2      Trapped in a frozen car during a blizzard, a p...      1720.0
# 3      Upon moving into a new place, a 20-something r...      1147.0
# 4      Inspired by her moms rebellious past and a con...        63.0
# ...                                                  ...         ...
# 15475  Seung Yeon decides to chase her dream of becom...         NaN
# 15476  Shrek celebrates Halloween, Puss in Boots is c...         NaN
# 15477  Madagascar goes wild with holiday spirit in th...        71.0
# 15478  Join your DreamWorks friends for these four ho...        82.0
# 15479  In this pair of adventures, Po tells the story...        17.0
#
#                                                    Image  \
# 0      https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
# 1      https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 2      https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 3      https://occ-0-1489-1490.1.nflxso.net/dnm/api/v...
# 4      https://occ-0-4039-1500.1.nflxso.net/dnm/api/v...
# ...                                                  ...
# 15475  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
# 15476  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
# 15477  https://occ-0-2773-2774.1.nflxso.net/dnm/api/v...
# 15478  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
# 15479  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
#
#                                                   Poster  \
# 0      https://m.media-amazon.com/images/M/MV5BOWM4NT...
# 1      https://m.media-amazon.com/images/M/MV5BZGUyN2...
# 2      https://m.media-amazon.com/images/M/MV5BODM2MD...
# 3      https://m.media-amazon.com/images/M/MV5BNWRkMz...
# 4      https://m.media-amazon.com/images/M/MV5BODYyNW...
# ...                                                  ...
# 15475                                                NaN
# 15476                                                NaN
# 15477                                                NaN
# 15478                                                NaN
# 15479                                                NaN
#
#                                       TMDb Trailer Trailer Site
# 0                                              NaN          NaN
# 1      https://www.youtube.com/watch?v=eIbcxPy4okQ      YouTube
# 2      https://www.youtube.com/watch?v=0RvV7TNUlkQ      YouTube
# 3                                              NaN          NaN
# 4                                              NaN          NaN
# ...                                            ...          ...
# 15475                                          NaN          NaN
# 15476                                          NaN          NaN
# 15477                                          NaN          NaN
# 15478                                          NaN          NaN
# 15479                                          NaN          NaN
#
# [15480 rows x 29 columns]

# %% [markdown]
# ### * So:
#
# ### --- `import pandas as pd` loads the pandas module.
# ### --- `pd.read_csv()` produces a `DataFrame` object from a Comma Separated Value (or CSV) spreadsheet, the simplest way to create a `DataFrame`
# ### --- A `DataFrame` is essentially a table.  It has many rows, each with their own row index (which by default is 0-based numbering), and many columns, each with their own name.  Every row has a value for each column.  When you print a `DataFrame`, it shows it as a truncated table.
# ### --- If `df` is the name of a `DataFrame`, then`df.columns` would provide the column names of this `DataFrame`. (When you load a spreadsheet into a `DataFrame`, pandas is smart enough to figure out that the top row is probably column names, rather than data!)
# ### --- If you want to look at the first 5 rows of `df` just to see what the data "looks like", use `df.head()`.
#
#
# <br><br><br><br><br>
# <br><br><br><br><br>
#
#
# # 2. Selecting Columns with Dictionary-like Syntax
#
# ### * Think of a `DataFrame` as being almost like a dictionary: *keys* would be the column names, and the *values* would be the list of values in each column.  (Actually, the proper pandas name for the "list" of values is `Series`.)

# %%
# EXAMPLE 2a: Dictionary-like syntax

import pandas as pd
netflix_df = pd.read_csv('netflix.csv')

# We're treating netflix_df like a dictionary here.
# The key is a column name, the value is the column itself.
one_col = netflix_df['Title']
print(one_col)

# Note that when you print out the names, you the corresponding row indices are also displayed.
# Out:
# 0                                 Lets Fight Ghost
# 1                              HOW TO BUILD A GIRL
# 2                                       Centigrade
# 3                                            ANNE+
# 4                                            Moxie
#                            ...
# 15475                       K-POP Extreme Survival
# 15476              DreamWorks Shreks Swamp Stories
# 15477    DreamWorks Happy Holidays from Madagascar
# 15478                  DreamWorks Holiday Classics
# 15479     DreamWorks Kung Fu Panda Awesome Secrets
# Name: Title, Length: 15480, dtype: object

# %%
# EXAMPLE 2b: More dictionary-like syntax

import pandas as pd
netflix_df = pd.read_csv('netflix.csv')

# Here's something you CAN'T do with dictionaries:
# instead of providing ONE key, you can provide a LIST of them.
# (This of course makes perfect sense for tables.)

smaller_df = netflix_df[ ['Title', 'Director', 'IMDb Score'] ]
print(smaller_df)

# %% [markdown]
# ### * If `df` is a `DataFrame`:
#
# ### --- `df[ <column_name> ]` produces a new smaller `DataFrame`: one that contains only one column, with the given name.  Because this is a `DataFrame`, it also still has row indices.
# ### --- `df[ <list> ]` also produces a smaller `DataFrame`, which contains all the columns whose names are in `<list>`.
#
# <br><br><br><br><br>
# <br><br><br><br><br>
#
#
#
#
# # 3. Selecting Rows with `.iloc[]`
#
# ### * If you want to select a subset of rows from a `DataFrame`, we'll use `.iloc[]` (short for "index location").

# %%
# EXAMPLE 3a: .iloc[] and .at[]

import pandas as pd
netflix_df = pd.read_csv('netflix.csv')

# This is how you select just row 5540 (actually, the sixth row)
print('############################\nRow 5540:\n############################\n')
print(netflix_df.iloc[5540])   # Note the SQUARE brackets: .iloc isn't a function!


# And this is how you select several rows
print('\n############################\nRows 840-850:\n############################\n')
print(netflix_df.iloc[840:850])
# Out:
# ############################
# Row 5540:
# ############################
#
# Title                                                           Its Bruno!
# Genre                                                               Comedy
# Tags                                   TV Comedies,US TV Shows,US TV Shows
# Languages                                                          English
# Series or Movie                                                     Series
# Hidden Gem Score                                                       7.5
# Country Availability     India,Lithuania,Portugal,Brazil,Israel,Argenti...
# Runtime                                                       < 30 minutes
# Director                                                               NaN
# Writer                                                         Solvan Naim
# Actors                     Solvan Naim, Donnell Rawlings, Bruno, Sam Eliad
# View Rating                                                          TV-MA
# IMDb Score                                                             7.5
# Rotten Tomatoes Score                                                  NaN
# Metacritic Score                                                       NaN
# Awards Received                                                        1.0
# Awards Nominated For                                                   NaN
# Boxoffice                                                              NaN
# Release Date                                                     17-May-19
# Netflix Release Date                                             5/17/2019
# Production House                                                       NaN
# Netflix Link                        https://www.netflix.com/watch/80999455
# IMDb Link                            https://www.imdb.com/title/tt10186846
# Summary                  An old-school Brooklyn native devotes his days...
# IMDb Votes                                                          2501.0
# Image                    https://occ-0-1490-1489.1.nflxso.net/dnm/api/v...
# Poster                   https://m.media-amazon.com/images/M/MV5BZmY1Nj...
# TMDb Trailer                                                           NaN
# Trailer Site                                                           NaN
# Name: 5540, dtype: object
#
# ############################
# Rows 840-850:
# ############################
#
#                                    Title  \
# 840              Godzilla vs. Destoroyah
# 841               Godzilla vs. Biollante
# 842           Godzilla vs. King Ghidorah
# 843  Godzilla & Mothra: Battle for Earth
# 844                 Godzilla Raids Again
# 845        Godzilla vs. Mechagodzilla II
# 846           Godzilla vs. Mechagodzilla
# 847                 Godzilla vs. Hedorah
# 848                   Godzilla vs. Gigan
# 849                             Godzilla
#
#                                                  Genre  \
# 840                             Action, Horror, Sci-Fi
# 841                                     Action, Sci-Fi
# 842         Action, Adventure, Drama, Sci-Fi, Thriller
# 843                Action, Adventure, Sci-Fi, Thriller
# 844                             Action, Horror, Sci-Fi
# 845                   Action, Adventure, Drama, Sci-Fi
# 846                    Action, Fantasy, Horror, Sci-Fi
# 847  Animation, Action, Adventure, Horror, Music, S...
# 848          Action, Adventure, Family, Horror, Sci-Fi
# 849                Action, Adventure, Sci-Fi, Thriller
#
#                                                   Tags  \
# 840  Action & Adventure,Sci-Fi & Fantasy,Action Sci...
# 841  Action & Adventure,Sci-Fi & Fantasy,Action Sci...
# 842  Action & Adventure,Sci-Fi & Fantasy,Action Sci...
# 843                   Sci-Fi & Fantasy,Japanese Movies
# 844  Action & Adventure,Sci-Fi & Fantasy,Action Sci...
# 845  Action & Adventure,Sci-Fi & Fantasy,Action Sci...
# 846  Action & Adventure,Sci-Fi & Fantasy,Action Sci...
# 847  Sci-Fi & Fantasy,Japanese Movies,Classic Movie...
# 848  Action & Adventure,Sci-Fi & Fantasy,Action Sci...
# 849  Action & Adventure,Sci-Fi & Fantasy,Action Sci...
#
#                       Languages Series or Movie  Hidden Gem Score  \
# 840           Japanese, English           Movie               6.5
# 841           Japanese, English           Movie               5.8
# 842           Japanese, English           Movie               5.2
# 843           English, Japanese           Movie               3.4
# 844                    Japanese           Movie               5.1
# 845  Japanese, English, Russian           Movie               6.5
# 846                    Japanese           Movie               5.5
# 847                    Japanese           Movie               5.6
# 848                    Japanese           Movie               6.0
# 849           English, Japanese           Movie               3.4
#
#     Country Availability   Runtime  \
# 840                Japan  1-2 hour
# 841                Japan  1-2 hour
# 842                Japan  1-2 hour
# 843                Japan  1-2 hour
# 844                Japan  1-2 hour
# 845                Japan  1-2 hour
# 846                Japan  1-2 hour
# 847                Japan  1-2 hour
# 848                Japan  1-2 hour
# 849                Japan  1-2 hour
#
#                                               Director  \
# 840  Kazuki Ohmori, Koji Hashimoto, Takao Okawara, ...
# 841      Kenjirô Ohmori, Kazuki Ohmori, Koji Hashimoto
# 842    Katsumune Ishida, Kazuki Ohmori, Koji Hashimoto
# 843                                     Gareth Edwards
# 844                        Ishirô Honda, Motoyoshi Oda
# 845                       Kazuki Ohmori, Takao Okawara
# 846                                         Jun Fukuda
# 847                     Ishirô Honda, Yoshimitsu Banno
# 848  Jun Fukuda, Ishirô Honda, Yoshimitsu Banno, Sh...
# 849                                     Gareth Edwards
#
#                                                 Writer  ...  \
# 840  Hideki Oka, Kazuki Ohmori, Minoru Yoshida, Shi...  ...
# 841  Shin'ichi Sekizawa, Kazuki Ohmori, Shinichirô ...  ...
# 842                                      Kazuki Ohmori  ...
# 843  Shigeru Kayama, Takeo Murata, Dave Callaham, M...  ...
# 844  Shigeru Kayama, Ib Melchior, Takeo Murata, Shi...  ...
# 845  Wataru Mimura, Andrew Smith, Minoru Yoshida, S...  ...
# 846  Masami Fukushima, Hiroyasu Yamaura, Jun Fukuda...  ...
# 847                   Takeshi Kimura, Yoshimitsu Banno  ...
# 848                 Shin'ichi Sekizawa, Takeshi Kimura  ...
# 849  Shigeru Kayama, Takeo Murata, Dave Callaham, M...  ...
#
#     Netflix Release Date    Production House  \
# 840            12/1/2020   Toho Company Ltd.
# 841            12/1/2020             Miramax
# 842            12/1/2020   Toho Company Ltd.
# 843            12/1/2020  Legendary Pictures
# 844            12/1/2020                 NaN
# 845            12/1/2020   Toho Company Ltd.
# 846            12/1/2020   Toho Company Ltd.
# 847            12/1/2020                 NaN
# 848            12/1/2020                 NaN
# 849            12/1/2020  Legendary Pictures
#
#                                Netflix Link  \
# 840  https://www.netflix.com/watch/81318385
# 841  https://www.netflix.com/watch/70259668
# 842  https://www.netflix.com/watch/70128707
# 843  https://www.netflix.com/watch/70128706
# 844  https://www.netflix.com/watch/70059917
# 845  https://www.netflix.com/watch/70020236
# 846  https://www.netflix.com/watch/70012281
# 847  https://www.netflix.com/watch/70012280
# 848  https://www.netflix.com/watch/70012279
# 849  https://www.netflix.com/watch/60035960
#
#                                 IMDb Link  \
# 840  https://www.imdb.com/title/tt0113187
# 841  https://www.imdb.com/title/tt0097444
# 842  https://www.imdb.com/title/tt0101962
# 843  https://www.imdb.com/title/tt0831387
# 844  https://www.imdb.com/title/tt0048127
# 845  https://www.imdb.com/title/tt0107027
# 846  https://www.imdb.com/title/tt0071565
# 847  https://www.imdb.com/title/tt0067148
# 848  https://www.imdb.com/title/tt0068371
# 849  https://www.imdb.com/title/tt0831387
#
#                                                Summary  IMDb Votes  \
# 840  As humanity races to stop the catastrophic nuc...      5492.0
# 841  When experimenting with Godzilla cells, scient...      5176.0
# 842  Humans from the future travel back in time to ...      5702.0
# 843  Six months after a meteorite strike, larvae of...    377876.0
# 844  Two pilots make an emergency landing on a remo...      5711.0
# 845  An infant Godzilla’s telepathic call lures the...      4412.0
# 846  Alien invaders hatch a plot to conquer Earth w...      5720.0
# 847  A flying Godzilla comes to save the day when a...      4801.0
# 848  Using an amusement park as its base, an alien ...      4197.0
# 849  Awakened by nuclear weapons testing, an ancien...    377876.0
#
#                                                  Image  \
# 840  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
# 841  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
# 842  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
# 843  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
# 844  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
# 845  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
# 846  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
# 847  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
# 848  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
# 849  https://occ-0-3467-3466.1.nflxso.net/dnm/api/v...
#
#                                                 Poster  \
# 840  https://m.media-amazon.com/images/M/MV5BYjQzOT...
# 841  https://m.media-amazon.com/images/M/MV5BODZjOW...
# 842  https://m.media-amazon.com/images/M/MV5BMjE2Nz...
# 843  https://m.media-amazon.com/images/M/MV5BN2E4ZD...
# 844  https://m.media-amazon.com/images/M/MV5BM2QwOG...
# 845  https://m.media-amazon.com/images/M/MV5BMmEwMG...
# 846  https://m.media-amazon.com/images/M/MV5BMmNjMW...
# 847  https://m.media-amazon.com/images/M/MV5BMjUzNz...
# 848  https://m.media-amazon.com/images/M/MV5BNGU4NT...
# 849  https://m.media-amazon.com/images/M/MV5BN2E4ZD...
#
#                                     TMDb Trailer Trailer Site
# 840  https://www.youtube.com/watch?v=NEHDDxNOybk      YouTube
# 841  https://www.youtube.com/watch?v=ZypCEzH9OKk      YouTube
# 842  https://www.youtube.com/watch?v=2GWl-wrwN2g      YouTube
# 843  https://www.youtube.com/watch?v=oHKGx1pzczg      YouTube
# 844  https://www.youtube.com/watch?v=hH7MA-KlUBo      YouTube
# 845  https://www.youtube.com/watch?v=TvbWZB1k5t0      YouTube
# 846  https://www.youtube.com/watch?v=8sb7e0iKqWI      YouTube
# 847  https://www.youtube.com/watch?v=a6c_LuvJRuQ      YouTube
# 848  https://www.youtube.com/watch?v=GslZKWemeEs      YouTube
# 849  https://www.youtube.com/watch?v=oHKGx1pzczg      YouTube
#
# [10 rows x 29 columns]

# %% [markdown]
# ### * If `df` is a DataFrame,
#
# ### --- `df.iloc[]` can be used to produce a new DataFrame which contains an individual row, or containing a range of rows (via slicing).  You can also combine this with column selection, as before.
#
# <br><br><br><br><br>
# <br><br><br><br><br>
#
#
# # 4.  Pause: Summary, Practice
#
# ### * `import pandas as pd` loads the pandas module.
# ### * `pd.read_csv()` produces a `DataFrame` object from a Comma Separated Value (or CSV) spreadsheet.
# ### * `df.columns` would provide the column names of this `df`.
# ### * `df.head()` provides the first 5 rows of `df`.
# ### * `df[ <column_name> ]` produces a new smaller `DataFrame`: one that contains only one column, with the given name.
# ### * `df[ <list> ]` also produces a smaller `DataFrame`, which contains all the columns whose names are in `<list>`.
# ### * `df.iloc[]` can be used to produce a new DataFrame which contains an individual row, or containing a range of rows (via slicing).  You can also combine this with column selection.

# %%
# EXAMPLE 4a: Basic .iloc[] practice

# How would you print just the Title, Director, and IMDb Score columns for just rows 1230 - 1240?

print(netflix_df.iloc[1230:1241][['Title', 'Director', 'IMDb Score']])
# Out:
#                                     Title           Director  IMDb Score
# 1230                                Jurek  Pawel Wysoczanski         7.4
# 1231                         Campo Grande       Sandra Kogut         6.3
# 1232                   Pagpag: Nine Lives      Frasco Mortiz         5.5
# 1233                           Rogue City    Olivier Marchal         6.1
# 1234  Guillermo Vilas: Settling the Score   Matías Gueilburt         7.1
# 1235                        Blood of Zeus                NaN         7.6
# 1236          Secrets of the Saqqara Tomb       James Tovell         7.3
# 1237                          Kaali Khuhi    Terrie Samundra         3.4
# 1238                            His House        Remi Weekes         6.5
# 1239                             Holidate                NaN         6.9
# 1240                          Gipsy Queen      Hüseyin Tabak         6.2

# %% [markdown]
# <br><br><br><br><br>
# <br><br><br><br><br>
#
# # 5. Column Operations
#
# ### * pandas allows you to perform operations on columns in a couple of different ways.
#
# ### * If you want to add or subtract or multiply or divide two columns, then pandas will perform those operations item-by-item, and produce a new column from them (if the two columns aren't the same size, funny things can happen).

# %%
# EXAMPLE 5a: Column operations

import pandas as pd
n_df = pd.read_csv('netflix.csv')

# Here is a basic column operation: subtracting two columns, to produce a new
# column. (Obviously, ordinary Python lists don't behave this way!!!!)

new_col = n_df['Rotten Tomatoes Score'] - n_df['Metacritic Score']

print(new_col)

# %% [markdown]
# <br><br><br><br><br>
# <br><br><br><br><br>
#
#
# # 6. Broadcasting
#
# ### * You can also perform an operation between a column and a single value. pandas will interpret such an expression to mean that you want to perform that operation between your single value and *each individual entry* of the column, to form a new column.
#
# ### * This is called *broadcasting*.

# %%
# EXAMPLE 6a: More column operations

import pandas as pd
n_df = pd.read_csv('netflix.csv')

imdb_col = 10 * n_df['IMDb Score']

# n_df['IMDb Score'] is a column, whereas 10 is just a plain old number.  
# However, pandas is built to deal with operations like this.
# Whenever it sees an expression like "column times number", it multiplies the number by 
# EACH ENTRY of the column. This is called BROADCASTING.
print(imdb_col)

# %%
# EXAMPLE 6b: Boolean broadcasting

import pandas as pd
n_df = pd.read_csv('netflix.csv')

# As we'll see, broadcasting is particularly useful for Boolean operations.
# The following, for example, creates a column which contains True and False values.

my_bool_col = n_df['IMDb Score'] > 8.0
print(my_bool_col)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15475    False
# 15476    False
# 15477    False
# 15478    False
# 15479    False
# Name: IMDb Score, Length: 15480, dtype: bool

# %% [markdown]
# <br><br><br><br><br>
# <br><br><br><br><br>
#
# # 7. Boolean Indexing
#
# ### * Suppose that you have a `DataFrame` called `df`, and that you also have a column `b` of Boolean values of the same length.   Then `df[b]` will produce a new `DataFrame` with fewer rows: specifically, it will keep all the rows of `df` where `b` has the value `True`, and throw out all the values of `df` where `b` has the value `False`.
#
# ### * This is called *Boolean indexing*.
#
# ### * Note: before, when we wrote something like `df[ ]`, we were selecting **columns**, whereas now we're using `df[  ]` to select **rows**.
#
# ### * The difference is what goes inside those square brackets: pandas is smart enough to know that if there is a list of strings, it's selecting columns, and if there is a pandas column containing Boolean values, it's selecting rows.

# %%
# EXAMPLE 7a: Boolean indexing with DataFrames

import pandas as pd
n_df = pd.read_csv('netflix.csv')

# First, identify the movie with an IMDb Score of at least 8

#above8_df = n_df[ n_df['IMDb Score'] > 8 ]
#print(above8_df)

# Now, select the movies

onlytrueabove8_df = n_df[ n_df['IMDb Score'] > 8 ]

#print(onlytrueabove8_df)
# Out:
#   Cell In[4], line 13
#     onlytrueabove8_df = ['IMDb Score']n_df[ n_df['IMDb Score'] > 8 ]
#                                       ^
# SyntaxError: invalid syntax

# %%
# EXAMPLE 7b: Let's get the names of the movies that have at least 100000 votes on IMDb

# The desired column name is 'IMDb Votes'

import pandas as pd
n_df = pd.read_csv('netflix.csv')

# The desired column name is 'IMDb Votes'

titles = n_df[ n_df['IMDb Votes'] >= 100000 ]['Title']

# Now, get the titles of the selected movies

print(titles)
# Out:
# 0                                Lets Fight Ghost
# 15                                          Joker
# 16                                              I
# 17                               Harrys Daughters
# 69                                    Stand by Me
#                            ...
# 15453                                3:10 to Yuma
# 15456                              50 First Dates
# 15457                                          21
# 15460    The Twilight Saga: Breaking Dawn: Part 1
# 15465                              13 Going on 30
# Name: Title, Length: 1517, dtype: object

# %% [markdown]
# <br><br><br><br><br>
# <br><br><br><br><br>
#
# # 8. More Sophisticated Boolean Operations: Watch Out!
#
# ### * If you want to perform more sophisticated Boolean operations involving multiple columns, you can, but there are a couple of sticking points:
#
# ### --- Use parentheses LIBERALLY.
#
# ### --- `and` doesn't work for pandas columns -- use `&` in its place.  Likewise, use `|` in place of `or`, and `~` in place of `not`.
#
# bitwise boolean can be thought of an element by element comparison of two boolean lists

# %%
# EXAMPLE 8a: Composite Boolean indexing

import pandas as pd
n_df = pd.read_csv('netflix.csv')


# Let's get the movies that have high IMDb ratings AND high votes

# This feels like it should work.  But it doesn't. 
#(So, COMMENT IT OUT!)
# select = n_df['IMDb Score'] > 8.0 and n_df['IMDb Votes'] > 100000

# Instead, you should use the AMPERSAND, &, instead. But, this doesn't work either.
#(So, COMMENT THIS OUT TOO!)
# select = n_df['IMDb Score'] > 8.0 & n_df['IMDb Votes'] > 100000

# FINALLY: put both individual expressions in parentheses.
select = (n_df['IMDb Score'] > 8.0) & (n_df['IMDb Votes'] > 100000)


# Now, we can use this column to select the best movies.  
print(n_df[select][ ['Title', 'IMDb Score'] ])
# Out:
#                                        Title  IMDb Score
# 15                                     Joker         8.4
# 17                          Harrys Daughters         8.1
# 69                               Stand by Me         8.1
# 294                                 The Hunt         8.3
# 420                         The Elephant Man         8.1
# ...                                      ...         ...
# 15389             Avatar: The Last Airbender         9.2
# 15394                                  Seven         8.6
# 15406                           Breaking Bad         9.5
# 15409                         House of Cards         8.7
# 15429  The Lord of the Rings: The Two Towers         8.7
#
# [224 rows x 2 columns]

# %% [markdown]
# <br><br><br><br><br>
# <br><br><br><br><br>
#
# # 9. Iterating Through DataFrames
#
# ### * Looping through `DataFrame`s is discouraged.  That being said, given that I'm giving a limited introduction to pandas, perhaps you should be aware of how to loop through a `DataFrame`.
#
# ### * Tempting:

# %%
for row in df:
    <do something with <row>>

# %% [markdown]
# ### * But that probably doesn't do what you want.

# %%
# EXAMPLE 9a: Looping through a DataFrame gives column names :(

import pandas as pd
n_df = pd.read_csv('netflix.csv')

for r in n_df:
    print('*', r)
    
# It's going to just print the names of the columns.  That could be useful,
# but it sure wasn't what I was expecting.
# Out:
# * Title
# * Genre
# * Tags
# * Languages
# * Series or Movie
# * Hidden Gem Score
# * Country Availability
# * Runtime
# * Director
# * Writer
# * Actors
# * View Rating
# * IMDb Score
# * Rotten Tomatoes Score
# * Metacritic Score
# * Awards Received
# * Awards Nominated For
# * Boxoffice
# * Release Date
# * Netflix Release Date
# * Production House
# * Netflix Link
# * IMDb Link
# * Summary
# * IMDb Votes
# * Image
# * Poster
# * TMDb Trailer
# * Trailer Site

# %% [markdown]
# <br><br><br><br><br>
# <br><br><br><br><br>
#
# ### * So, how can I loop through the rows of a `DataFrame`?  Preferred way is to use `.iterrows()`.
#
#
# ### * If `df` is a `DataFrame`, then

# %%
for idx, r in df.iterrows():

# %% [markdown]
# ### will loop through the rows of `df`.  For each iteration of the loop, `idx` will be assigned to be the *index* of one row after another, and `r` will be assigned to be the corresponding *row itself*.
#
# ### * If you are interested not in entire rows, but just some specific columns in each row, you can write `r[<col name>]` to retreive a specific entry in the row `r`.

# %%
# EXAMPLE 9b: .iterrows()

import pandas as pd
n_df = pd.read_csv('netflix.csv')

shorter_df = n_df[ (n_df['IMDb Score'] > 8.0) & (n_df['IMDb Votes'] > 100000) ]

for idx, r in shorter_df.iterrows():
    print('Row', idx, ':', r['Title'], r['Genre']) # idx will be the row index
# Out:
# Row 15 : Joker Crime, Drama, Thriller
# Row 17 : Harrys Daughters Adventure, Drama, Fantasy, Mystery
# Row 69 : Stand by Me Adventure, Drama
# Row 294 : The Hunt Drama
# Row 420 : The Elephant Man Biography, Drama
# Row 696 : Me & You vs The World Biography, Crime, Drama
# Row 864 : Fiction. Crime, Drama
# Row 1138 : Girls Revenge Drama, Mystery, Thriller
# Row 1208 : Homeland Crime, Drama, Mystery, Thriller
# Row 1217 : 1917 Drama, Thriller, War
# Row 1256 : Rebecca Drama, Mystery, Romance, Thriller
# Row 1337 : Spotlight Biography, Crime, Drama
# Row 1358 : Aliens Action, Adventure, Sci-Fi, Thriller
# Row 1594 : Parasite Comedy, Drama, Thriller
# Row 1640 : Cobra Kai Action, Comedy, Drama, Sport
# Row 1721 : Joker Crime, Drama, Thriller
# Row 1754 : Grave Animation, Drama, War
# Row 1903 : Downton Abbey Drama, Romance
# Row 2789 : 2 дня Action, Sci-Fi
# Row 2840 : Честное пионерское 2 Action, Sci-Fi
# Row 2843 : Честное пионерское 3 Animation, Adventure, Comedy, Family, Fantasy
# Row 3265 : The Kid Comedy, Drama, Family
# Row 3359 : The Gold Rush Adventure, Comedy, Drama, Western
# Row 3362 : City Lights Comedy, Drama, Romance
# Row 3441 : The 400 Blows Crime, Drama
# Row 3632 : Howl’s Moving Castle Animation, Adventure, Family, Fantasy
# Row 3811 : Nausicaä of the Valley of the Wind Animation, Adventure, Fantasy, Sci-Fi
# Row 4230 : The Witcher Action, Adventure, Fantasy, Mystery
# Row 4424 : Gods Little Village Crime, Drama
# Row 4516 : Klaus Animation, Adventure, Comedy, Family
# Row 4602 : Three Billboards Outside Ebbing, Missouri Comedy, Crime, Drama
# Row 4868 : Green Book Biography, Comedy, Drama, Music
# Row 5340 : Spider-Man: Into the Spider-Verse Animation, Action, Adventure, Family, Sci-Fi
# Row 6364 : Sex Education Comedy, Drama
# Row 6634 : Blade Runner: The Final Cut Action, Sci-Fi, Thriller
# Row 6834 : Death Note Animation, Crime, Drama, Fantasy, Mystery, Thriller
# Row 6858 : Alien Horror, Sci-Fi
# Row 6981 : The Haunting of Hill House Drama, Horror, Mystery, Thriller
# Row 8258 : Aliens Action, Adventure, Sci-Fi, Thriller
# Row 8645 : Monty Python and the Holy Grail Adventure, Comedy, Fantasy
# Row 8646 : Monty Pythons Life of Brian Comedy
# Row 9049 : The End of the F***ing World Adventure, Comedy, Crime, Drama, Romance, Thriller
# Row 9245 : Lagaan Drama, Musical, Sport
# Row 9246 : Taare Zameen Par Drama, Family
# Row 9251 : Your Name Animation, Drama, Fantasy, Romance
# Row 9260 : Dark Crime, Drama, Mystery, Sci-Fi, Thriller
# Row 9265 : Cool Hand Luke Crime, Drama
# Row 9302 : Marvels The Punisher Action, Crime, Drama, Thriller
# Row 9370 : Grave of the Fireflies Animation, Drama, War
# Row 9410 : MINDHUNTER Crime, Drama, Thriller
# Row 9464 : The Handmaiden Drama, Romance, Thriller
# Row 9489 : This Is Us Comedy, Drama, Romance
# Row 9600 : The Good Place Comedy, Drama, Fantasy, Romance
# Row 9698 : Ozark Crime, Drama, Thriller
# Row 9749 : La casa de papel Action, Crime, Mystery, Thriller
# Row 9769 : Contratiempo Crime, Drama, Mystery, Thriller
# Row 9811 : Dangal Action, Biography, Drama, Sport
# Row 9975 : Hacksaw Ridge Biography, Drama, History, War
# Row 10265 : One Punch Man Animation, Action, Comedy, Fantasy, Sci-Fi
# Row 10551 : Room Drama, Thriller
# Row 10726 : The Crown Biography, Drama, History
# Row 10832 : Memories of Murder Crime, Drama, Mystery, Thriller
# Row 10860 : The Green Mile Crime, Drama, Fantasy, Mystery
# Row 11183 : Stranger Things Drama, Fantasy, Horror, Mystery, Sci-Fi, Thriller
# Row 11259 : Spotlight Biography, Crime, Drama
# Row 11334 : Harry Potter and the Deathly Hallows: Part 2 Adventure, Drama, Fantasy, Mystery
# Row 11423 : Mad Max: Fury Road Action, Adventure, Sci-Fi, Thriller
# Row 11425 : Rick and Morty Animation, Adventure, Comedy, Sci-Fi
# Row 11443 : Outlander Drama, Fantasy, Romance
# Row 11450 : Die Hard Action, Thriller
# Row 11508 : Blade Runner: Theatrical Cut Action, Sci-Fi, Thriller
# Row 11510 : Princess Mononoke Animation, Action, Adventure, Fantasy
# Row 11511 : My Neighbor Totoro Animation, Family, Fantasy
# Row 11515 : Spirited Away Animation, Adventure, Family, Fantasy, Mystery
# Row 11589 : Das Boot: Theatrical Cut Adventure, Drama, Thriller, War
# Row 11633 : Gone with the Wind Drama, History, Romance, War
# Row 11976 : Modern Times Comedy, Drama, Family, Romance
# Row 11980 : Rashomon Crime, Drama, Mystery
# Row 11985 : The Great Dictator Comedy, Drama, War
# Row 12015 : How to Get Away with Murder Crime, Drama, Mystery, Thriller
# Row 12034 : Interstellar Adventure, Drama, Sci-Fi
# Row 12053 : Unforgiven Drama, Western
# Row 12104 : A Beautiful Mind Biography, Drama
# Row 12113 : Indiana Jones and the Last Crusade Action, Adventure
# Row 12135 : 2001: A Space Odyssey Adventure, Sci-Fi
# Row 12150 : Indiana Jones and the Raiders of the Lost Ark Action, Adventure
# Row 12174 : Das Boot: Directors Cut Adventure, Drama, Thriller, War
# Row 12177 : Lawrence of Arabia: Restored Version Adventure, Biography, Drama, History, War
# Row 12186 : Narcos Biography, Crime, Drama, Thriller
# Row 12346 : Sense8 Drama, Mystery, Sci-Fi, Thriller
# Row 12350 : Apocalypse Now Redux Drama, Mystery, War
# Row 12357 : Gone Girl Drama, Mystery, Thriller
# Row 12455 : Mr. Bean: The Whole Bean Comedy, Family
# Row 12597 : Rush Action, Biography, Drama, Sport
# Row 12808 : Persona Drama, Thriller
# Row 13250 : Monty Pythons Fliegender Zirkus Adventure, Comedy, Fantasy
# Row 13317 : Shameless (U.S.) Comedy, Drama
# Row 13319 : Prisoners Crime, Drama, Mystery, Thriller
# Row 13360 : The Dark Knight Rises Action, Adventure
# Row 13369 : Requiem for a Dream Drama
# Row 13450 : Hannibal Crime, Drama, Horror, Mystery, Thriller
# Row 13494 : Community Comedy
# Row 13510 : The Grand Budapest Hotel Adventure, Comedy, Crime
# Row 13550 : 12 Years a Slave Biography, Drama, History
# Row 13622 : Cinema Paradiso Drama, Romance
# Row 13647 : Rang De Basanti Comedy, Crime, Drama
# Row 13851 : Star Trek: The Next Generation Action, Adventure, Mystery, Sci-Fi
# Row 13857 : Gilmore Girls Comedy, Drama
# Row 13937 : Braveheart Biography, Drama, History, War
# Row 13944 : Peaky Blinders Crime, Drama
# Row 13948 : Black Mirror Drama, Sci-Fi, Thriller
# Row 13974 : Parks and Recreation Comedy
# Row 13976 : Attack on Titan Animation, Action, Adventure, Drama, Fantasy, Horror
# Row 13977 : Its Always Sunny in Philadelphia Comedy
# Row 14030 : The Lives of Others Drama, Mystery, Thriller
# Row 14043 : The Great Escape Adventure, Drama, History, Thriller, War
# Row 14066 : Fullmetal Alchemist: Brotherhood Animation, Action, Adventure, Comedy, Drama, Fantasy, Sci-Fi
# Row 14086 : Memento Mystery, Thriller
# Row 14121 : Taxi Driver Crime, Drama
# Row 14136 : The Pianist Biography, Drama, Music, War
# Row 14149 : The IT Crowd Comedy
# Row 14150 : Casino Crime, Drama
# Row 14170 : The Intouchables Biography, Comedy, Drama
# Row 14207 : V for Vendetta Action, Drama, Sci-Fi, Thriller
# Row 14216 : Terminator 2: Judgment Day Action, Sci-Fi
# Row 14220 : Lock, Stock and Two Smoking Barrels Action, Comedy, Crime
# Row 14242 : The Truman Show Comedy, Drama
# Row 14250 : The Usual Suspects Crime, Mystery, Thriller
# Row 14263 : Twin Peaks Crime, Drama, Mystery, Thriller
# Row 14267 : Saving Private Ryan Drama, War
# Row 14290 : The Matrix Action, Sci-Fi
# Row 14291 : The Mentalist Crime, Drama, Mystery, Thriller
# Row 14296 : Silence of the Lambs Crime, Drama, Thriller
# Row 14304 : The Shining Drama, Horror
# Row 14331 : Inception Action, Adventure, Sci-Fi, Thriller
# Row 14350 : Gran Torino Drama
# Row 14356 : GoodFellas Biography, Crime, Drama
# Row 14367 : The Lord of the Rings: The Fellowship of the Ring Action, Adventure, Drama, Fantasy
# Row 14375 : Full Metal Jacket Drama, War
# Row 14377 : Fargo Crime, Drama, Thriller
# Row 14387 : Eternal Sunshine of the Spotless Mind Drama, Romance, Sci-Fi
# Row 14400 : The Departed Crime, Drama, Thriller
# Row 14409 : Penny Dreadful Drama, Fantasy, Horror
# Row 14416 : Downfall Biography, Drama, History, War
# Row 14419 : Django Unchained Drama, Western
# Row 14449 : Million Dollar Baby Drama, Sport
# Row 14465 : Stand by Me Adventure, Drama
# Row 14478 : The Dark Knight Action, Crime, Drama, Thriller
# Row 14480 : Batman Begins Action, Adventure
# Row 14481 : The Big Bang Theory Comedy, Romance
# Row 14490 : A Clockwork Orange Crime, Drama, Sci-Fi
# Row 14523 : Brooklyn Nine-Nine Comedy, Crime
# Row 14583 : Suits Comedy, Drama
# Row 14591 : The Prestige Drama, Mystery, Sci-Fi, Thriller
# Row 14596 : Psycho Horror, Mystery, Thriller
# Row 14603 : The Office (U.S.) Comedy
# Row 14618 : Schindlers List Biography, Drama, History
# Row 14621 : The Shawshank Redemption Drama
# Row 14624 : Jurassic Park Action, Adventure, Sci-Fi, Thriller
# Row 14633 : Shutter Island Mystery, Thriller
# Row 14634 : Into the Wild Adventure, Biography, Drama
# Row 14657 : Homeland Crime, Drama, Mystery, Thriller
# Row 14666 : Gladiator Action, Adventure, Drama
# Row 14673 : No Country for Old Men Crime, Drama, Thriller
# Row 14677 : Scarface Crime, Drama
# Row 14684 : Modern Family Comedy, Drama, Romance
# Row 14685 : Forrest Gump Drama, Romance
# Row 14686 : Family Guy Animation, Comedy
# Row 14696 : The Godfather Crime, Drama
# Row 14708 : How to Train Your Dragon Animation, Action, Adventure, Family, Fantasy
# Row 14715 : Once Upon a Time in the West Western
# Row 14723 : Catch Me If You Can Biography, Crime, Drama
# Row 14727 : White Collar Comedy, Crime, Drama, Mystery
# Row 14729 : How I Met Your Mother Comedy, Romance
# Row 14730 : Criminal Minds Crime, Drama, Mystery, Thriller
# Row 14741 : Back to the Future Adventure, Comedy, Sci-Fi
# Row 14745 : Prison Break Action, Crime, Drama, Mystery, Thriller
# Row 14751 : Inglourious Basterds Adventure, Drama, War
# Row 14768 : American Beauty Drama
# Row 14780 : Sons of Anarchy Crime, Drama, Thriller
# Row 14786 : Arrested Development Comedy
# Row 14808 : The Godfather: Part II Crime, Drama
# Row 14817 : 24 Action, Crime, Drama, Thriller
# Row 14833 : There Will Be Blood Drama
# Row 14837 : Warrior Action, Drama, Sport
# Row 14842 : Vikings Action, Adventure, Drama, History, Romance, War
# Row 14858 : Trainspotting Drama
# Row 14866 : Snatch Comedy, Crime
# Row 14872 : Sherlock Crime, Drama, Mystery, Thriller
# Row 14874 : Supernatural Drama, Fantasy, Horror, Mystery, Thriller
# Row 14876 : Spartacus Action, Adventure, Biography, Drama, History, Romance
# Row 14889 : Rocky Drama, Sport
# Row 14900 : Platoon Drama, War
# Row 14916 : The Originals Drama, Fantasy, Horror, Mystery
# Row 14966 : Luther Crime, Drama, Mystery, Thriller
# Row 14971 : Leon: The Professional Action, Crime, Drama, Thriller
# Row 14992 : The Legend of Korra Animation, Action, Adventure, Comedy, Drama, Family, Fantasy, Sci-Fi
# Row 15023 : Hotel Rwanda Biography, Drama, History, War
# Row 15061 : Top Gear Adventure, Comedy, Reality-TV, Talk-Show
# Row 15063 : Good Will Hunting Drama, Romance
# Row 15093 : Pulp Fiction Crime, Drama
# Row 15102 : Friends Comedy, Romance
# Row 15119 : The Lord of the Rings: The Return of the King Action, Adventure, Drama, Fantasy
# Row 15121 : The Wolf of Wall Street Biography, Crime, Drama
# Row 15138 : Reservoir Dogs Crime, Drama, Thriller
# Row 15141 : Pans Labyrinth Drama, Fantasy, War
# Row 15168 : The Walking Dead Drama, Horror, Thriller
# Row 15172 : Death Note Animation, Crime, Drama, Fantasy, Mystery, Thriller
# Row 15174 : Marvels Daredevil Action, Crime, Drama, Fantasy, Sci-Fi, Thriller
# Row 15243 : BoJack Horseman Animation, Comedy, Drama
# Row 15252 : Orphan Black Action, Drama, Sci-Fi
# Row 15255 : Oldboy Action, Drama, Mystery, Thriller
# Row 15272 : Orange Is the New Black Comedy, Crime, Drama
# Row 15285 : Better Call Saul Crime, Drama
# Row 15289 : The Good, the Bad and the Ugly Western
# Row 15323 : Hachi: A Dogs Tale Biography, Drama, Family
# Row 15330 : American History X Drama
# Row 15383 : Archer Animation, Action, Comedy
# Row 15384 : Amelie Comedy, Romance
# Row 15389 : Avatar: The Last Airbender Animation, Action, Adventure, Family, Fantasy, Mystery
# Row 15394 : Seven Crime, Drama, Mystery, Thriller
# Row 15406 : Breaking Bad Crime, Drama, Thriller
# Row 15409 : House of Cards Drama
# Row 15429 : The Lord of the Rings: The Two Towers Action, Adventure, Drama, Fantasy

# %%
# EXAMPLE 9c: Genres

import pandas as pd
n_df = pd.read_csv('netflix.csv')

shorter_df = n_df[ (n_df['IMDb Score'] > 8.0) & (n_df['IMDb Votes'] > 100000) ]

genre_keyword = 'Comedy'

# Let's identify the best movies in a given genre

for idx, r in shorter_df.iterrows():
    if genre_keyword in r['Genre']:
        print('Row', idx, ':', f'{r['Title']:<10}', '|', r['Genre'])
# Out:
#   Cell In[17], line 14
#     print('Row', idx, ':', f'{r['Title']:<10}', '|', r['Genre'])
#                                  ^
# SyntaxError: f-string: unmatched '['

# %% [markdown]
# <br><br><br><br><br>
#
# # 10. Basic Statistics
#
# ### --- `df.describe()` and `df.corr()` give basic statistical info about the columns (the latter provides correlations between columns).

# %%
# EXAMPLE 10a: .describe()

import pandas as pd
n_df = pd.read_csv('netflix.csv')

n_df.describe()
# Out:
#        Hidden Gem Score    IMDb Score  Rotten Tomatoes Score  \
# count      13379.000000  13381.000000            6382.000000
# mean           5.937551      6.496054              59.523034
# std            2.250202      1.146910              26.999173
# min            0.600000      1.000000               0.000000
# 25%            3.800000      5.800000              38.000000
# 50%            6.800000      6.600000              64.000000
# 75%            7.900000      7.300000              83.000000
# max            9.800000      9.700000             100.000000
#
#        Metacritic Score  Awards Received  Awards Nominated For    IMDb Votes
# count       4336.000000      6075.000000           7661.000000  1.337900e+04
# mean          56.813653         8.764444             13.983161  4.272841e+04
# std           17.582545        18.311171             29.821052  1.257012e+05
# min            5.000000         1.000000              1.000000  5.000000e+00
# 25%           44.000000         1.000000              2.000000  4.035000e+02
# 50%           57.000000         3.000000              5.000000  2.322000e+03
# 75%           70.000000         8.000000             12.000000  2.089050e+04
# max          100.000000       300.000000            386.000000  2.354197e+06

# %%
# EXAMPLE 10b: .corr()

import pandas as pd
n_df = pd.read_csv('netflix.csv')

n_df.corr('pearson',1,True)
# Out:
#                        Hidden Gem Score  IMDb Score  Rotten Tomatoes Score  \
# Hidden Gem Score               1.000000    0.120373               0.397905
# IMDb Score                     0.120373    1.000000               0.710922
# Rotten Tomatoes Score          0.397905    0.710922               1.000000
# Metacritic Score               0.521470    0.717715               0.903345
# Awards Received               -0.112787    0.291142               0.301380
# Awards Nominated For          -0.159500    0.289843               0.309572
# IMDb Votes                    -0.359540    0.229760               0.181762
#
#                        Metacritic Score  Awards Received  \
# Hidden Gem Score               0.521470        -0.112787
# IMDb Score                     0.717715         0.291142
# Rotten Tomatoes Score          0.903345         0.301380
# Metacritic Score               1.000000         0.431420
# Awards Received                0.431420         1.000000
# Awards Nominated For           0.449726         0.817262
# IMDb Votes                     0.261384         0.469818
#
#                        Awards Nominated For  IMDb Votes
# Hidden Gem Score                  -0.159500   -0.359540
# IMDb Score                         0.289843    0.229760
# Rotten Tomatoes Score              0.309572    0.181762
# Metacritic Score                   0.449726    0.261384
# Awards Received                    0.817262    0.469818
# Awards Nominated For               1.000000    0.497690
# IMDb Votes                         0.497690    1.000000

# %% [markdown]
# <br><br><br><br><br>
# <br><br><br><br><br>
#
#
# # 11. Dropping Missing Values With .dropna(), Sorting With .sort_values(), Scatter Plot

# %%
# EXAMPLE 11a: Dropping Missing Values With .dropna

import pandas as pd
n_df = pd.read_csv('netflix.csv')

# This operation removes all entries where one of the corresponding columns is missing.
scores = n_df.dropna(subset = ['IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score'])

print(scores)

# %%
# EXAMPLE 11b: Sorting Values

import pandas as pd
n_df = pd.read_csv('netflix.csv')
scores = n_df.dropna(subset = ['IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score'])

# This sorts by Rotten Tomatoes Scores, then resolves ties by sorting by Metacritic Score
rtscores = scores.sort_values(by = ['Rotten Tomatoes Score', 'Metacritic Score'], ascending = False)


print(rtscores[['Title', 'Rotten Tomatoes Score', 'Metacritic Score', 'Genre']])

# %%
# EXAMPLE 11c: Plot

import pandas as pd
n_df = pd.read_csv('netflix.csv')
scores = n_df.dropna(subset = ['IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score'])

scores.plot.scatter('Rotten Tomatoes Score', 'Metacritic Score')

# What's that outlier?

# %%
# EXAMPLE 11d: Find the outlier

import pandas as pd
n_df = pd.read_csv('netflix.csv')
scores = n_df.dropna(subset = ['IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score'])

# FIND THE OUTLIER!

# %% [markdown]
# <br><br><br><br><br>
# <br><br><br><br><br>
#
# # 12. Final Summary
#
# ### * Tons more to say: you can create `DataFrame`s from other sources than CSV spreadsheets; you can create `DataFrame`s from scratch in Python, and then export them to spreadsheets; you can edit entries in a `DataFrame`, and add or delete columns; you can sort, reindex, perform simple statistics, etc.
#
#
# ### * Look at *Python for Data Analysis*, or the page http://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html, as starting points for further study.
#
# ### * Final summary (where `df` always denotes some `DataFrame` object):
#
# ### --- `import pandas as pd` loads the pandas module.
# ### --- `pd.read_csv()` produces a `DataFrame` object from a Comma Separated Value (or CSV) spreadsheet.
# ### --- `df.columns` would provide the column names of this `df`.
# ### --- `df.head()` provides the first 5 rows of `df`.
# ### --- `df[ <column_name> ]` produces a new smaller `DataFrame`: one that contains only one column, with the given name.
# ### --- `df[ <list> ]` also produces a smaller `DataFrame`, which contains all the columns whose names are in `<list>`.
# ### --- `df.iloc[]` can be used to produce a new DataFrame which contains an individual row, or containing a range of rows (via slicing).  You can also combine this with column selection.
# ### --- You can perform column operations to create new columns.
# ### --- If you create a Boolean column called `b` (of the same si, then `df[b]` will select the rows from `df` where `b` has the value `True`.
# ### --- `for idx, r in df.iterrows():` will iterate through the rows of `df`: for each row in `df`, `idx` will be assigned the row index, and `r` will be assigned the row itself.
# ### --- `df.describe()` and `df.corr()` give basic statistical info about the DataFrame.
# ### --- `df.dropna(subset = ['Col name 1', 'Col name 2'])` produces a dataframe where rows with missing values in the given columns are dropped.
# ### --- `df.sort_values(by = ['Col name 1', 'Col name 2'])` sorts the dataframe, first on one column, then resolving ties by sorting on a second column.
# ### --- `df.plot.scatter('Col name 1', 'Col name 2')` produces a scatter plot of your data set.

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br>
#
# # 13. Recursion
#
# ### * Recall that $n!$, read as n factorial, is an important mathematical operation.  How can we implement it as a function?  Well, a loop's not too hard.

# %%
# EXAMPLE 13a: Factorial function

def factorial(n):
    """Return n factorial."""
    product = 1
    # Multiply product by each number between 1 and n. 
    for factor in range (1, n+1):
        product *= factor
    return product

print(factorial(5), ' (should be 120)')
print(factorial(42), ' (should be...big)')
print(factorial(0), ' (0! = 1 by definition)')

# %% [markdown]
# <br><br><br><br><br>
# <br><br><br><br><br>
#
# ### * $n!$ can ALSO be defined by:
#
# * $0! = 1$
# * $n! = n \cdot (n-1)!$ if $n \geq 1$
#
# ### * For example, $5! = 5\cdot 4 \cdot 3 \cdot 2 \cdot 1 = 5 \cdot (4 \cdot 3 \cdot 2 \cdot 1) = 5\cdot 4!$.
#
# ### * Can you use a function to compute the value of *that same* function?  Let's give it a try!

# %%
# EXAMPLE 1b: Recursive factorial

def rfact(n):
    """Return n factorial, computed recursively."""
    if n <= 1:
        return 1
    else:
        return n * rfact(n-1)
    
print(rfact(4))

# %% [markdown]
# ### * This is an example of a **recursive function**: this simply means a function that makes a call to itself.
#
# ### * Recursive functions will have some simple base cases (like $1! = 1$) that can be computed without recurvise calls.
#
# ### * Furthermore, an effective recursive function will frequently find the answer to a "big" problem using calls to the same function applied to a "smaller" problem.  (For example, to compute $10!$, first we solve the smaller problem $9!$, and multiply the answer by 10.)
